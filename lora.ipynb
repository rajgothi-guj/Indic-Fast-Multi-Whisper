# %%
import argparse
import random
from torch.cuda.amp import autocast, GradScaler
import numpy as np
import torch
from torch import nn
import torch.nn.functional as F
import whisper
from tqdm import tqdm
from whisper.tokenizer import get_tokenizer
# from data_utils.dataloader import get_dataloader
# from model.prompting import Prompting, Prompting_len0

import os
import loralib as lora

tokenizer = get_tokenizer(multilingual=True, task="transcribe")
model = whisper.load_model("large-v3", 'cuda')
#  -1 is for the special token `sot_prev` and the other half is for the transcribed tokens
max_prompt_length = model.dims.n_text_ctx // 2 - 1

# %%
model
# Out:
# Whisper(
#   (encoder): AudioEncoder(
#     (conv1): Conv1d(128, 1280, kernel_size=(3,), stride=(1,), padding=(1,))
#     (conv2): Conv1d(1280, 1280, kernel_size=(3,), stride=(2,), padding=(1,))
#     (blocks): ModuleList(
#       (0-31): 32 x ResidualAttentionBlock(
#         (attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=1280, out_features=5120, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=5120, out_features=1280, bias=True)
#         )
#         (mlp_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (ln_post): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): TextDecoder(
#     (token_embedding): Embedding(51866, 1280)
#     (blocks): ModuleList(
#       (0-31): 32 x ResidualAttentionBlock(
#         (attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (cross_attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (cross_attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=1280, out_features=5120, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=5120, out_features=1280, bias=True)
#         )
#         (mlp_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#   )
# )

# %%
# freeze the whole whisper model
for p in model.parameters():
    p.requires_grad = False

# %%
class System(nn.Module):
    def __init__(self, model, prompt):
        super(System, self).__init__()
        self.prompt = prompt
        self.model = model
        self.emb, self.hook = self.install_forward_hook()

    def forward(self, x, xvec, y_in):
        self.emb[self.model.encoder.conv2], _ = self.prompt(xvec)
        logits = self.model.decoder(y_in, self.model.encoder(x))
        return logits

    def install_forward_hook(self):
        hooks = []
        weight = {}
        layer = self.model.encoder.conv2

        def cln_func(module, _, output):
            output[:, :, 0] = weight[module]
            return output
        hooks.append(layer.register_forward_hook(cln_func))
        return weight, hooks

def set_module(model, submodule_key, module):
    tokens = submodule_key.split('.')
    sub_tokens = tokens[:-1]
    cur_mod = model
    for s in sub_tokens:
        cur_mod = getattr(cur_mod, s)
    setattr(cur_mod, tokens[-1], module)


def process_model(model):
    load_layer = ['query', 'value']
    for module in model.named_modules():
        if any(c in module[0] for c in load_layer):
            # print(module[0])
            # print()
            lora_layer = lora.Linear(module[1].in_features, module[1].out_features, r=4,
                                     bias=hasattr(module[1], 'bias'), merge_weights=False)
            lora_layer.weight = module[1].weight
            if hasattr(module[1], 'bias'):
                lora_layer.bias = module[1].bias
            set_module(model, module[0], lora_layer)
    return None

# %%
process_model(model)
# Out:
# encoder.blocks.0.attn.query
#
# encoder.blocks.0.attn.value
#
# encoder.blocks.1.attn.query
#
# encoder.blocks.1.attn.value
#
# encoder.blocks.2.attn.query
#
# encoder.blocks.2.attn.value
#
# encoder.blocks.3.attn.query
#
# encoder.blocks.3.attn.value
#
# encoder.blocks.4.attn.query
#
# encoder.blocks.4.attn.value
#
# encoder.blocks.5.attn.query
#
# encoder.blocks.5.attn.value
#
# encoder.blocks.6.attn.query
#
# encoder.blocks.6.attn.value
#
# encoder.blocks.7.attn.query
#
# encoder.blocks.7.attn.value
#
# encoder.blocks.8.attn.query
#
# encoder.blocks.8.attn.value
#
# encoder.blocks.9.attn.query
#
# encoder.blocks.9.attn.value
#
# encoder.blocks.10.attn.query
#
# encoder.blocks.10.attn.value
#
# encoder.blocks.11.attn.query
#
# encoder.blocks.11.attn.value
#
# encoder.blocks.12.attn.query
#
# encoder.blocks.12.attn.value
#
# encoder.blocks.13.attn.query
#
# encoder.blocks.13.attn.value
#
# encoder.blocks.14.attn.query
#
# encoder.blocks.14.attn.value
#
# encoder.blocks.15.attn.query
#
# encoder.blocks.15.attn.value
#
# encoder.blocks.16.attn.query
#
# encoder.blocks.16.attn.value
#
# encoder.blocks.17.attn.query
#
# encoder.blocks.17.attn.value
#
# encoder.blocks.18.attn.query
#
# encoder.blocks.18.attn.value
#
# encoder.blocks.19.attn.query
#
# encoder.blocks.19.attn.value
#
# encoder.blocks.20.attn.query
#
# encoder.blocks.20.attn.value
#
# encoder.blocks.21.attn.query
#
# encoder.blocks.21.attn.value
#
# encoder.blocks.22.attn.query
#
# encoder.blocks.22.attn.value
#
# encoder.blocks.23.attn.query
#
# encoder.blocks.23.attn.value
#
# encoder.blocks.24.attn.query
#
# encoder.blocks.24.attn.value
#
# encoder.blocks.25.attn.query
#
# encoder.blocks.25.attn.value
#
# encoder.blocks.26.attn.query
#
# encoder.blocks.26.attn.value
#
# encoder.blocks.27.attn.query
#
# encoder.blocks.27.attn.value
#
# encoder.blocks.28.attn.query
#
# encoder.blocks.28.attn.value
#
# encoder.blocks.29.attn.query
#
# encoder.blocks.29.attn.value
#
# encoder.blocks.30.attn.query
#
# encoder.blocks.30.attn.value
#
# encoder.blocks.31.attn.query
#
# encoder.blocks.31.attn.value
#
# decoder.blocks.0.attn.query
#
# decoder.blocks.0.attn.value
#
# decoder.blocks.0.cross_attn.query
#
# decoder.blocks.0.cross_attn.value
#
# decoder.blocks.1.attn.query
#
# decoder.blocks.1.attn.value
#
# decoder.blocks.1.cross_attn.query
#
# decoder.blocks.1.cross_attn.value
#
# decoder.blocks.2.attn.query
#
# decoder.blocks.2.attn.value
#
# decoder.blocks.2.cross_attn.query
#
# decoder.blocks.2.cross_attn.value
#
# decoder.blocks.3.attn.query
#
# decoder.blocks.3.attn.value
#
# decoder.blocks.3.cross_attn.query
#
# decoder.blocks.3.cross_attn.value
#
# decoder.blocks.4.attn.query
#
# decoder.blocks.4.attn.value
#
# decoder.blocks.4.cross_attn.query
#
# decoder.blocks.4.cross_attn.value
#
# decoder.blocks.5.attn.query
#
# decoder.blocks.5.attn.value
#
# decoder.blocks.5.cross_attn.query
#
# decoder.blocks.5.cross_attn.value
#
# decoder.blocks.6.attn.query
#
# decoder.blocks.6.attn.value
#
# decoder.blocks.6.cross_attn.query
#
# decoder.blocks.6.cross_attn.value
#
# decoder.blocks.7.attn.query
#
# decoder.blocks.7.attn.value
#
# decoder.blocks.7.cross_attn.query
#
# decoder.blocks.7.cross_attn.value
#
# decoder.blocks.8.attn.query
#
# decoder.blocks.8.attn.value
#
# decoder.blocks.8.cross_attn.query
#
# decoder.blocks.8.cross_attn.value
#
# decoder.blocks.9.attn.query
#
# decoder.blocks.9.attn.value
#
# decoder.blocks.9.cross_attn.query
#
# decoder.blocks.9.cross_attn.value
#
# decoder.blocks.10.attn.query
#
# decoder.blocks.10.attn.value
#
# decoder.blocks.10.cross_attn.query
#
# decoder.blocks.10.cross_attn.value
#
# decoder.blocks.11.attn.query
#
# decoder.blocks.11.attn.value
#
# decoder.blocks.11.cross_attn.query
#
# decoder.blocks.11.cross_attn.value
#
# decoder.blocks.12.attn.query
#
# decoder.blocks.12.attn.value
#
# decoder.blocks.12.cross_attn.query
#
# decoder.blocks.12.cross_attn.value
#
# decoder.blocks.13.attn.query
#
# decoder.blocks.13.attn.value
#
# decoder.blocks.13.cross_attn.query
#
# decoder.blocks.13.cross_attn.value
#
# decoder.blocks.14.attn.query
#
# decoder.blocks.14.attn.value
#
# decoder.blocks.14.cross_attn.query
#
# decoder.blocks.14.cross_attn.value
#
# decoder.blocks.15.attn.query
#
# decoder.blocks.15.attn.value
#
# decoder.blocks.15.cross_attn.query
#
# decoder.blocks.15.cross_attn.value
#
# decoder.blocks.16.attn.query
#
# decoder.blocks.16.attn.value
#
# decoder.blocks.16.cross_attn.query
#
# decoder.blocks.16.cross_attn.value
#
# decoder.blocks.17.attn.query
#
# decoder.blocks.17.attn.value
#
# decoder.blocks.17.cross_attn.query
#
# decoder.blocks.17.cross_attn.value
#
# decoder.blocks.18.attn.query
#
# decoder.blocks.18.attn.value
#
# decoder.blocks.18.cross_attn.query
#
# decoder.blocks.18.cross_attn.value
#
# decoder.blocks.19.attn.query
#
# decoder.blocks.19.attn.value
#
# decoder.blocks.19.cross_attn.query
#
# decoder.blocks.19.cross_attn.value
#
# decoder.blocks.20.attn.query
#
# decoder.blocks.20.attn.value
#
# decoder.blocks.20.cross_attn.query
#
# decoder.blocks.20.cross_attn.value
#
# decoder.blocks.21.attn.query
#
# decoder.blocks.21.attn.value
#
# decoder.blocks.21.cross_attn.query
#
# decoder.blocks.21.cross_attn.value
#
# decoder.blocks.22.attn.query
#
# decoder.blocks.22.attn.value
#
# decoder.blocks.22.cross_attn.query
#
# decoder.blocks.22.cross_attn.value
#
# decoder.blocks.23.attn.query
#
# decoder.blocks.23.attn.value
#
# decoder.blocks.23.cross_attn.query
#
# decoder.blocks.23.cross_attn.value
#
# decoder.blocks.24.attn.query
#
# decoder.blocks.24.attn.value
#
# decoder.blocks.24.cross_attn.query
#
# decoder.blocks.24.cross_attn.value
#
# decoder.blocks.25.attn.query
#
# decoder.blocks.25.attn.value
#
# decoder.blocks.25.cross_attn.query
#
# decoder.blocks.25.cross_attn.value
#
# decoder.blocks.26.attn.query
#
# decoder.blocks.26.attn.value
#
# decoder.blocks.26.cross_attn.query
#
# decoder.blocks.26.cross_attn.value
#
# decoder.blocks.27.attn.query
#
# decoder.blocks.27.attn.value
#
# decoder.blocks.27.cross_attn.query
#
# decoder.blocks.27.cross_attn.value
#
# decoder.blocks.28.attn.query
#
# decoder.blocks.28.attn.value
#
# decoder.blocks.28.cross_attn.query
#
# decoder.blocks.28.cross_attn.value
#
# decoder.blocks.29.attn.query
#
# decoder.blocks.29.attn.value
#
# decoder.blocks.29.cross_attn.query
#
# decoder.blocks.29.cross_attn.value
#
# decoder.blocks.30.attn.query
#
# decoder.blocks.30.attn.value
#
# decoder.blocks.30.cross_attn.query
#
# decoder.blocks.30.cross_attn.value
#
# decoder.blocks.31.attn.query
#
# decoder.blocks.31.attn.value
#
# decoder.blocks.31.cross_attn.query
#
# decoder.blocks.31.cross_attn.value

# %%
model
# Out:
# Whisper(
#   (encoder): AudioEncoder(
#     (conv1): Conv1d(128, 1280, kernel_size=(3,), stride=(1,), padding=(1,))
#     (conv2): Conv1d(1280, 1280, kernel_size=(3,), stride=(2,), padding=(1,))
#     (blocks): ModuleList(
#       (0-31): 32 x ResidualAttentionBlock(
#         (attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=1280, out_features=5120, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=5120, out_features=1280, bias=True)
#         )
#         (mlp_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (ln_post): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): TextDecoder(
#     (token_embedding): Embedding(51866, 1280)
#     (blocks): ModuleList(
#       (0-31): 32 x ResidualAttentionBlock(
#         (attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (cross_attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (cross_attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=1280, out_features=5120, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=5120, out_features=1280, bias=True)
#         )
#         (mlp_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#   )
# )

# %%
lora.mark_only_lora_as_trainable(model, bias='lora_only')

# %%
model
# Out:
# Whisper(
#   (encoder): AudioEncoder(
#     (conv1): Conv1d(128, 1280, kernel_size=(3,), stride=(1,), padding=(1,))
#     (conv2): Conv1d(1280, 1280, kernel_size=(3,), stride=(2,), padding=(1,))
#     (blocks): ModuleList(
#       (0-31): 32 x ResidualAttentionBlock(
#         (attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=1280, out_features=5120, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=5120, out_features=1280, bias=True)
#         )
#         (mlp_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (ln_post): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): TextDecoder(
#     (token_embedding): Embedding(51866, 1280)
#     (blocks): ModuleList(
#       (0-31): 32 x ResidualAttentionBlock(
#         (attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (cross_attn): MultiHeadAttention(
#           (query): Linear(in_features=1280, out_features=1280, bias=True)
#           (key): Linear(in_features=1280, out_features=1280, bias=False)
#           (value): Linear(in_features=1280, out_features=1280, bias=True)
#           (out): Linear(in_features=1280, out_features=1280, bias=True)
#         )
#         (cross_attn_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#         (mlp): Sequential(
#           (0): Linear(in_features=1280, out_features=5120, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=5120, out_features=1280, bias=True)
#         )
#         (mlp_ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       )
#     )
#     (ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#   )
# )

# %%
for name,param in model.named_parameters():
    print(name,param.requires_grad)
# Out:
# encoder.conv1.weight False
# encoder.conv1.bias False
# encoder.conv2.weight False
# encoder.conv2.bias False
# encoder.blocks.0.attn.query.weight False
# encoder.blocks.0.attn.query.bias True
# encoder.blocks.0.attn.query.lora_A True
# encoder.blocks.0.attn.query.lora_B True
# encoder.blocks.0.attn.key.weight False
# encoder.blocks.0.attn.value.weight False
# encoder.blocks.0.attn.value.bias True
# encoder.blocks.0.attn.value.lora_A True
# encoder.blocks.0.attn.value.lora_B True
# encoder.blocks.0.attn.out.weight False
# encoder.blocks.0.attn.out.bias False
# encoder.blocks.0.attn_ln.weight False
# encoder.blocks.0.attn_ln.bias False
# encoder.blocks.0.mlp.0.weight False
# encoder.blocks.0.mlp.0.bias False
# encoder.blocks.0.mlp.2.weight False
# encoder.blocks.0.mlp.2.bias False
# encoder.blocks.0.mlp_ln.weight False
# encoder.blocks.0.mlp_ln.bias False
# encoder.blocks.1.attn.query.weight False
# encoder.blocks.1.attn.query.bias True
# encoder.blocks.1.attn.query.lora_A True
# encoder.blocks.1.attn.query.lora_B True
# encoder.blocks.1.attn.key.weight False
# encoder.blocks.1.attn.value.weight False
# encoder.blocks.1.attn.value.bias True
# encoder.blocks.1.attn.value.lora_A True
# encoder.blocks.1.attn.value.lora_B True
# encoder.blocks.1.attn.out.weight False
# encoder.blocks.1.attn.out.bias False
# encoder.blocks.1.attn_ln.weight False
# encoder.blocks.1.attn_ln.bias False
# encoder.blocks.1.mlp.0.weight False
# encoder.blocks.1.mlp.0.bias False
# encoder.blocks.1.mlp.2.weight False
# encoder.blocks.1.mlp.2.bias False
# encoder.blocks.1.mlp_ln.weight False
# encoder.blocks.1.mlp_ln.bias False
# encoder.blocks.2.attn.query.weight False
# encoder.blocks.2.attn.query.bias True
# encoder.blocks.2.attn.query.lora_A True
# encoder.blocks.2.attn.query.lora_B True
# encoder.blocks.2.attn.key.weight False
# encoder.blocks.2.attn.value.weight False
# encoder.blocks.2.attn.value.bias True
# encoder.blocks.2.attn.value.lora_A True
# encoder.blocks.2.attn.value.lora_B True
# encoder.blocks.2.attn.out.weight False
# encoder.blocks.2.attn.out.bias False
# encoder.blocks.2.attn_ln.weight False
# encoder.blocks.2.attn_ln.bias False
# encoder.blocks.2.mlp.0.weight False
# encoder.blocks.2.mlp.0.bias False
# encoder.blocks.2.mlp.2.weight False
# encoder.blocks.2.mlp.2.bias False
# encoder.blocks.2.mlp_ln.weight False
# encoder.blocks.2.mlp_ln.bias False
# encoder.blocks.3.attn.query.weight False
# encoder.blocks.3.attn.query.bias True
# encoder.blocks.3.attn.query.lora_A True
# encoder.blocks.3.attn.query.lora_B True
# encoder.blocks.3.attn.key.weight False
# encoder.blocks.3.attn.value.weight False
# encoder.blocks.3.attn.value.bias True
# encoder.blocks.3.attn.value.lora_A True
# encoder.blocks.3.attn.value.lora_B True
# encoder.blocks.3.attn.out.weight False
# encoder.blocks.3.attn.out.bias False
# encoder.blocks.3.attn_ln.weight False
# encoder.blocks.3.attn_ln.bias False
# encoder.blocks.3.mlp.0.weight False
# encoder.blocks.3.mlp.0.bias False
# encoder.blocks.3.mlp.2.weight False
# encoder.blocks.3.mlp.2.bias False
# encoder.blocks.3.mlp_ln.weight False
# encoder.blocks.3.mlp_ln.bias False
# encoder.blocks.4.attn.query.weight False
# encoder.blocks.4.attn.query.bias True
# encoder.blocks.4.attn.query.lora_A True
# encoder.blocks.4.attn.query.lora_B True
# encoder.blocks.4.attn.key.weight False
# encoder.blocks.4.attn.value.weight False
# encoder.blocks.4.attn.value.bias True
# encoder.blocks.4.attn.value.lora_A True
# encoder.blocks.4.attn.value.lora_B True
# encoder.blocks.4.attn.out.weight False
# encoder.blocks.4.attn.out.bias False
# encoder.blocks.4.attn_ln.weight False
# encoder.blocks.4.attn_ln.bias False
# encoder.blocks.4.mlp.0.weight False
# encoder.blocks.4.mlp.0.bias False
# encoder.blocks.4.mlp.2.weight False
# encoder.blocks.4.mlp.2.bias False
# encoder.blocks.4.mlp_ln.weight False
# encoder.blocks.4.mlp_ln.bias False
# encoder.blocks.5.attn.query.weight False
# encoder.blocks.5.attn.query.bias True
# encoder.blocks.5.attn.query.lora_A True
# encoder.blocks.5.attn.query.lora_B True
# encoder.blocks.5.attn.key.weight False
# encoder.blocks.5.attn.value.weight False
# encoder.blocks.5.attn.value.bias True
# encoder.blocks.5.attn.value.lora_A True
# encoder.blocks.5.attn.value.lora_B True
# encoder.blocks.5.attn.out.weight False
# encoder.blocks.5.attn.out.bias False
# encoder.blocks.5.attn_ln.weight False
# encoder.blocks.5.attn_ln.bias False
# encoder.blocks.5.mlp.0.weight False
# encoder.blocks.5.mlp.0.bias False
# encoder.blocks.5.mlp.2.weight False
# encoder.blocks.5.mlp.2.bias False
# encoder.blocks.5.mlp_ln.weight False
# encoder.blocks.5.mlp_ln.bias False
# encoder.blocks.6.attn.query.weight False
# encoder.blocks.6.attn.query.bias True
# encoder.blocks.6.attn.query.lora_A True
# encoder.blocks.6.attn.query.lora_B True
# encoder.blocks.6.attn.key.weight False
# encoder.blocks.6.attn.value.weight False
# encoder.blocks.6.attn.value.bias True
# encoder.blocks.6.attn.value.lora_A True
# encoder.blocks.6.attn.value.lora_B True
# encoder.blocks.6.attn.out.weight False
# encoder.blocks.6.attn.out.bias False
# encoder.blocks.6.attn_ln.weight False
# encoder.blocks.6.attn_ln.bias False
# encoder.blocks.6.mlp.0.weight False
# encoder.blocks.6.mlp.0.bias False
# encoder.blocks.6.mlp.2.weight False
# encoder.blocks.6.mlp.2.bias False
# encoder.blocks.6.mlp_ln.weight False
# encoder.blocks.6.mlp_ln.bias False
# encoder.blocks.7.attn.query.weight False
# encoder.blocks.7.attn.query.bias True
# encoder.blocks.7.attn.query.lora_A True
# encoder.blocks.7.attn.query.lora_B True
# encoder.blocks.7.attn.key.weight False
# encoder.blocks.7.attn.value.weight False
# encoder.blocks.7.attn.value.bias True
# encoder.blocks.7.attn.value.lora_A True
# encoder.blocks.7.attn.value.lora_B True
# encoder.blocks.7.attn.out.weight False
# encoder.blocks.7.attn.out.bias False
# encoder.blocks.7.attn_ln.weight False
# encoder.blocks.7.attn_ln.bias False
# encoder.blocks.7.mlp.0.weight False
# encoder.blocks.7.mlp.0.bias False
# encoder.blocks.7.mlp.2.weight False
# encoder.blocks.7.mlp.2.bias False
# encoder.blocks.7.mlp_ln.weight False
# encoder.blocks.7.mlp_ln.bias False
# encoder.blocks.8.attn.query.weight False
# encoder.blocks.8.attn.query.bias True
# encoder.blocks.8.attn.query.lora_A True
# encoder.blocks.8.attn.query.lora_B True
# encoder.blocks.8.attn.key.weight False
# encoder.blocks.8.attn.value.weight False
# encoder.blocks.8.attn.value.bias True
# encoder.blocks.8.attn.value.lora_A True
# encoder.blocks.8.attn.value.lora_B True
# encoder.blocks.8.attn.out.weight False
# encoder.blocks.8.attn.out.bias False
# encoder.blocks.8.attn_ln.weight False
# encoder.blocks.8.attn_ln.bias False
# encoder.blocks.8.mlp.0.weight False
# encoder.blocks.8.mlp.0.bias False
# encoder.blocks.8.mlp.2.weight False
# encoder.blocks.8.mlp.2.bias False
# encoder.blocks.8.mlp_ln.weight False
# encoder.blocks.8.mlp_ln.bias False
# encoder.blocks.9.attn.query.weight False
# encoder.blocks.9.attn.query.bias True
# encoder.blocks.9.attn.query.lora_A True
# encoder.blocks.9.attn.query.lora_B True
# encoder.blocks.9.attn.key.weight False
# encoder.blocks.9.attn.value.weight False
# encoder.blocks.9.attn.value.bias True
# encoder.blocks.9.attn.value.lora_A True
# encoder.blocks.9.attn.value.lora_B True
# encoder.blocks.9.attn.out.weight False
# encoder.blocks.9.attn.out.bias False
# encoder.blocks.9.attn_ln.weight False
# encoder.blocks.9.attn_ln.bias False
# encoder.blocks.9.mlp.0.weight False
# encoder.blocks.9.mlp.0.bias False
# encoder.blocks.9.mlp.2.weight False
# encoder.blocks.9.mlp.2.bias False
# encoder.blocks.9.mlp_ln.weight False
# encoder.blocks.9.mlp_ln.bias False
# encoder.blocks.10.attn.query.weight False
# encoder.blocks.10.attn.query.bias True
# encoder.blocks.10.attn.query.lora_A True
# encoder.blocks.10.attn.query.lora_B True
# encoder.blocks.10.attn.key.weight False
# encoder.blocks.10.attn.value.weight False
# encoder.blocks.10.attn.value.bias True
# encoder.blocks.10.attn.value.lora_A True
# encoder.blocks.10.attn.value.lora_B True
# encoder.blocks.10.attn.out.weight False
# encoder.blocks.10.attn.out.bias False
# encoder.blocks.10.attn_ln.weight False
# encoder.blocks.10.attn_ln.bias False
# encoder.blocks.10.mlp.0.weight False
# encoder.blocks.10.mlp.0.bias False
# encoder.blocks.10.mlp.2.weight False
# encoder.blocks.10.mlp.2.bias False
# encoder.blocks.10.mlp_ln.weight False
# encoder.blocks.10.mlp_ln.bias False
# encoder.blocks.11.attn.query.weight False
# encoder.blocks.11.attn.query.bias True
# encoder.blocks.11.attn.query.lora_A True
# encoder.blocks.11.attn.query.lora_B True
# encoder.blocks.11.attn.key.weight False
# encoder.blocks.11.attn.value.weight False
# encoder.blocks.11.attn.value.bias True
# encoder.blocks.11.attn.value.lora_A True
# encoder.blocks.11.attn.value.lora_B True
# encoder.blocks.11.attn.out.weight False
# encoder.blocks.11.attn.out.bias False
# encoder.blocks.11.attn_ln.weight False
# encoder.blocks.11.attn_ln.bias False
# encoder.blocks.11.mlp.0.weight False
# encoder.blocks.11.mlp.0.bias False
# encoder.blocks.11.mlp.2.weight False
# encoder.blocks.11.mlp.2.bias False
# encoder.blocks.11.mlp_ln.weight False
# encoder.blocks.11.mlp_ln.bias False
# encoder.blocks.12.attn.query.weight False
# encoder.blocks.12.attn.query.bias True
# encoder.blocks.12.attn.query.lora_A True
# encoder.blocks.12.attn.query.lora_B True
# encoder.blocks.12.attn.key.weight False
# encoder.blocks.12.attn.value.weight False
# encoder.blocks.12.attn.value.bias True
# encoder.blocks.12.attn.value.lora_A True
# encoder.blocks.12.attn.value.lora_B True
# encoder.blocks.12.attn.out.weight False
# encoder.blocks.12.attn.out.bias False
# encoder.blocks.12.attn_ln.weight False
# encoder.blocks.12.attn_ln.bias False
# encoder.blocks.12.mlp.0.weight False
# encoder.blocks.12.mlp.0.bias False
# encoder.blocks.12.mlp.2.weight False
# encoder.blocks.12.mlp.2.bias False
# encoder.blocks.12.mlp_ln.weight False
# encoder.blocks.12.mlp_ln.bias False
# encoder.blocks.13.attn.query.weight False
# encoder.blocks.13.attn.query.bias True
# encoder.blocks.13.attn.query.lora_A True
# encoder.blocks.13.attn.query.lora_B True
# encoder.blocks.13.attn.key.weight False
# encoder.blocks.13.attn.value.weight False
# encoder.blocks.13.attn.value.bias True
# encoder.blocks.13.attn.value.lora_A True
# encoder.blocks.13.attn.value.lora_B True
# encoder.blocks.13.attn.out.weight False
# encoder.blocks.13.attn.out.bias False
# encoder.blocks.13.attn_ln.weight False
# encoder.blocks.13.attn_ln.bias False
# encoder.blocks.13.mlp.0.weight False
# encoder.blocks.13.mlp.0.bias False
# encoder.blocks.13.mlp.2.weight False
# encoder.blocks.13.mlp.2.bias False
# encoder.blocks.13.mlp_ln.weight False
# encoder.blocks.13.mlp_ln.bias False
# encoder.blocks.14.attn.query.weight False
# encoder.blocks.14.attn.query.bias True
# encoder.blocks.14.attn.query.lora_A True
# encoder.blocks.14.attn.query.lora_B True
# encoder.blocks.14.attn.key.weight False
# encoder.blocks.14.attn.value.weight False
# encoder.blocks.14.attn.value.bias True
# encoder.blocks.14.attn.value.lora_A True
# encoder.blocks.14.attn.value.lora_B True
# encoder.blocks.14.attn.out.weight False
# encoder.blocks.14.attn.out.bias False
# encoder.blocks.14.attn_ln.weight False
# encoder.blocks.14.attn_ln.bias False
# encoder.blocks.14.mlp.0.weight False
# encoder.blocks.14.mlp.0.bias False
# encoder.blocks.14.mlp.2.weight False
# encoder.blocks.14.mlp.2.bias False
# encoder.blocks.14.mlp_ln.weight False
# encoder.blocks.14.mlp_ln.bias False
# encoder.blocks.15.attn.query.weight False
# encoder.blocks.15.attn.query.bias True
# encoder.blocks.15.attn.query.lora_A True
# encoder.blocks.15.attn.query.lora_B True
# encoder.blocks.15.attn.key.weight False
# encoder.blocks.15.attn.value.weight False
# encoder.blocks.15.attn.value.bias True
# encoder.blocks.15.attn.value.lora_A True
# encoder.blocks.15.attn.value.lora_B True
# encoder.blocks.15.attn.out.weight False
# encoder.blocks.15.attn.out.bias False
# encoder.blocks.15.attn_ln.weight False
# encoder.blocks.15.attn_ln.bias False
# encoder.blocks.15.mlp.0.weight False
# encoder.blocks.15.mlp.0.bias False
# encoder.blocks.15.mlp.2.weight False
# encoder.blocks.15.mlp.2.bias False
# encoder.blocks.15.mlp_ln.weight False
# encoder.blocks.15.mlp_ln.bias False
# encoder.blocks.16.attn.query.weight False
# encoder.blocks.16.attn.query.bias True
# encoder.blocks.16.attn.query.lora_A True
# encoder.blocks.16.attn.query.lora_B True
# encoder.blocks.16.attn.key.weight False
# encoder.blocks.16.attn.value.weight False
# encoder.blocks.16.attn.value.bias True
# encoder.blocks.16.attn.value.lora_A True
# encoder.blocks.16.attn.value.lora_B True
# encoder.blocks.16.attn.out.weight False
# encoder.blocks.16.attn.out.bias False
# encoder.blocks.16.attn_ln.weight False
# encoder.blocks.16.attn_ln.bias False
# encoder.blocks.16.mlp.0.weight False
# encoder.blocks.16.mlp.0.bias False
# encoder.blocks.16.mlp.2.weight False
# encoder.blocks.16.mlp.2.bias False
# encoder.blocks.16.mlp_ln.weight False
# encoder.blocks.16.mlp_ln.bias False
# encoder.blocks.17.attn.query.weight False
# encoder.blocks.17.attn.query.bias True
# encoder.blocks.17.attn.query.lora_A True
# encoder.blocks.17.attn.query.lora_B True
# encoder.blocks.17.attn.key.weight False
# encoder.blocks.17.attn.value.weight False
# encoder.blocks.17.attn.value.bias True
# encoder.blocks.17.attn.value.lora_A True
# encoder.blocks.17.attn.value.lora_B True
# encoder.blocks.17.attn.out.weight False
# encoder.blocks.17.attn.out.bias False
# encoder.blocks.17.attn_ln.weight False
# encoder.blocks.17.attn_ln.bias False
# encoder.blocks.17.mlp.0.weight False
# encoder.blocks.17.mlp.0.bias False
# encoder.blocks.17.mlp.2.weight False
# encoder.blocks.17.mlp.2.bias False
# encoder.blocks.17.mlp_ln.weight False
# encoder.blocks.17.mlp_ln.bias False
# encoder.blocks.18.attn.query.weight False
# encoder.blocks.18.attn.query.bias True
# encoder.blocks.18.attn.query.lora_A True
# encoder.blocks.18.attn.query.lora_B True
# encoder.blocks.18.attn.key.weight False
# encoder.blocks.18.attn.value.weight False
# encoder.blocks.18.attn.value.bias True
# encoder.blocks.18.attn.value.lora_A True
# encoder.blocks.18.attn.value.lora_B True
# encoder.blocks.18.attn.out.weight False
# encoder.blocks.18.attn.out.bias False
# encoder.blocks.18.attn_ln.weight False
# encoder.blocks.18.attn_ln.bias False
# encoder.blocks.18.mlp.0.weight False
# encoder.blocks.18.mlp.0.bias False
# encoder.blocks.18.mlp.2.weight False
# encoder.blocks.18.mlp.2.bias False
# encoder.blocks.18.mlp_ln.weight False
# encoder.blocks.18.mlp_ln.bias False
# encoder.blocks.19.attn.query.weight False
# encoder.blocks.19.attn.query.bias True
# encoder.blocks.19.attn.query.lora_A True
# encoder.blocks.19.attn.query.lora_B True
# encoder.blocks.19.attn.key.weight False
# encoder.blocks.19.attn.value.weight False
# encoder.blocks.19.attn.value.bias True
# encoder.blocks.19.attn.value.lora_A True
# encoder.blocks.19.attn.value.lora_B True
# encoder.blocks.19.attn.out.weight False
# encoder.blocks.19.attn.out.bias False
# encoder.blocks.19.attn_ln.weight False
# encoder.blocks.19.attn_ln.bias False
# encoder.blocks.19.mlp.0.weight False
# encoder.blocks.19.mlp.0.bias False
# encoder.blocks.19.mlp.2.weight False
# encoder.blocks.19.mlp.2.bias False
# encoder.blocks.19.mlp_ln.weight False
# encoder.blocks.19.mlp_ln.bias False
# encoder.blocks.20.attn.query.weight False
# encoder.blocks.20.attn.query.bias True
# encoder.blocks.20.attn.query.lora_A True
# encoder.blocks.20.attn.query.lora_B True
# encoder.blocks.20.attn.key.weight False
# encoder.blocks.20.attn.value.weight False
# encoder.blocks.20.attn.value.bias True
# encoder.blocks.20.attn.value.lora_A True
# encoder.blocks.20.attn.value.lora_B True
# encoder.blocks.20.attn.out.weight False
# encoder.blocks.20.attn.out.bias False
# encoder.blocks.20.attn_ln.weight False
# encoder.blocks.20.attn_ln.bias False
# encoder.blocks.20.mlp.0.weight False
# encoder.blocks.20.mlp.0.bias False
# encoder.blocks.20.mlp.2.weight False
# encoder.blocks.20.mlp.2.bias False
# encoder.blocks.20.mlp_ln.weight False
# encoder.blocks.20.mlp_ln.bias False
# encoder.blocks.21.attn.query.weight False
# encoder.blocks.21.attn.query.bias True
# encoder.blocks.21.attn.query.lora_A True
# encoder.blocks.21.attn.query.lora_B True
# encoder.blocks.21.attn.key.weight False
# encoder.blocks.21.attn.value.weight False
# encoder.blocks.21.attn.value.bias True
# encoder.blocks.21.attn.value.lora_A True
# encoder.blocks.21.attn.value.lora_B True
# encoder.blocks.21.attn.out.weight False
# encoder.blocks.21.attn.out.bias False
# encoder.blocks.21.attn_ln.weight False
# encoder.blocks.21.attn_ln.bias False
# encoder.blocks.21.mlp.0.weight False
# encoder.blocks.21.mlp.0.bias False
# encoder.blocks.21.mlp.2.weight False
# encoder.blocks.21.mlp.2.bias False
# encoder.blocks.21.mlp_ln.weight False
# encoder.blocks.21.mlp_ln.bias False
# encoder.blocks.22.attn.query.weight False
# encoder.blocks.22.attn.query.bias True
# encoder.blocks.22.attn.query.lora_A True
# encoder.blocks.22.attn.query.lora_B True
# encoder.blocks.22.attn.key.weight False
# encoder.blocks.22.attn.value.weight False
# encoder.blocks.22.attn.value.bias True
# encoder.blocks.22.attn.value.lora_A True
# encoder.blocks.22.attn.value.lora_B True
# encoder.blocks.22.attn.out.weight False
# encoder.blocks.22.attn.out.bias False
# encoder.blocks.22.attn_ln.weight False
# encoder.blocks.22.attn_ln.bias False
# encoder.blocks.22.mlp.0.weight False
# encoder.blocks.22.mlp.0.bias False
# encoder.blocks.22.mlp.2.weight False
# encoder.blocks.22.mlp.2.bias False
# encoder.blocks.22.mlp_ln.weight False
# encoder.blocks.22.mlp_ln.bias False
# encoder.blocks.23.attn.query.weight False
# encoder.blocks.23.attn.query.bias True
# encoder.blocks.23.attn.query.lora_A True
# encoder.blocks.23.attn.query.lora_B True
# encoder.blocks.23.attn.key.weight False
# encoder.blocks.23.attn.value.weight False
# encoder.blocks.23.attn.value.bias True
# encoder.blocks.23.attn.value.lora_A True
# encoder.blocks.23.attn.value.lora_B True
# encoder.blocks.23.attn.out.weight False
# encoder.blocks.23.attn.out.bias False
# encoder.blocks.23.attn_ln.weight False
# encoder.blocks.23.attn_ln.bias False
# encoder.blocks.23.mlp.0.weight False
# encoder.blocks.23.mlp.0.bias False
# encoder.blocks.23.mlp.2.weight False
# encoder.blocks.23.mlp.2.bias False
# encoder.blocks.23.mlp_ln.weight False
# encoder.blocks.23.mlp_ln.bias False
# encoder.blocks.24.attn.query.weight False
# encoder.blocks.24.attn.query.bias True
# encoder.blocks.24.attn.query.lora_A True
# encoder.blocks.24.attn.query.lora_B True
# encoder.blocks.24.attn.key.weight False
# encoder.blocks.24.attn.value.weight False
# encoder.blocks.24.attn.value.bias True
# encoder.blocks.24.attn.value.lora_A True
# encoder.blocks.24.attn.value.lora_B True
# encoder.blocks.24.attn.out.weight False
# encoder.blocks.24.attn.out.bias False
# encoder.blocks.24.attn_ln.weight False
# encoder.blocks.24.attn_ln.bias False
# encoder.blocks.24.mlp.0.weight False
# encoder.blocks.24.mlp.0.bias False
# encoder.blocks.24.mlp.2.weight False
# encoder.blocks.24.mlp.2.bias False
# encoder.blocks.24.mlp_ln.weight False
# encoder.blocks.24.mlp_ln.bias False
# encoder.blocks.25.attn.query.weight False
# encoder.blocks.25.attn.query.bias True
# encoder.blocks.25.attn.query.lora_A True
# encoder.blocks.25.attn.query.lora_B True
# encoder.blocks.25.attn.key.weight False
# encoder.blocks.25.attn.value.weight False
# encoder.blocks.25.attn.value.bias True
# encoder.blocks.25.attn.value.lora_A True
# encoder.blocks.25.attn.value.lora_B True
# encoder.blocks.25.attn.out.weight False
# encoder.blocks.25.attn.out.bias False
# encoder.blocks.25.attn_ln.weight False
# encoder.blocks.25.attn_ln.bias False
# encoder.blocks.25.mlp.0.weight False
# encoder.blocks.25.mlp.0.bias False
# encoder.blocks.25.mlp.2.weight False
# encoder.blocks.25.mlp.2.bias False
# encoder.blocks.25.mlp_ln.weight False
# encoder.blocks.25.mlp_ln.bias False
# encoder.blocks.26.attn.query.weight False
# encoder.blocks.26.attn.query.bias True
# encoder.blocks.26.attn.query.lora_A True
# encoder.blocks.26.attn.query.lora_B True
# encoder.blocks.26.attn.key.weight False
# encoder.blocks.26.attn.value.weight False
# encoder.blocks.26.attn.value.bias True
# encoder.blocks.26.attn.value.lora_A True
# encoder.blocks.26.attn.value.lora_B True
# encoder.blocks.26.attn.out.weight False
# encoder.blocks.26.attn.out.bias False
# encoder.blocks.26.attn_ln.weight False
# encoder.blocks.26.attn_ln.bias False
# encoder.blocks.26.mlp.0.weight False
# encoder.blocks.26.mlp.0.bias False
# encoder.blocks.26.mlp.2.weight False
# encoder.blocks.26.mlp.2.bias False
# encoder.blocks.26.mlp_ln.weight False
# encoder.blocks.26.mlp_ln.bias False
# encoder.blocks.27.attn.query.weight False
# encoder.blocks.27.attn.query.bias True
# encoder.blocks.27.attn.query.lora_A True
# encoder.blocks.27.attn.query.lora_B True
# encoder.blocks.27.attn.key.weight False
# encoder.blocks.27.attn.value.weight False
# encoder.blocks.27.attn.value.bias True
# encoder.blocks.27.attn.value.lora_A True
# encoder.blocks.27.attn.value.lora_B True
# encoder.blocks.27.attn.out.weight False
# encoder.blocks.27.attn.out.bias False
# encoder.blocks.27.attn_ln.weight False
# encoder.blocks.27.attn_ln.bias False
# encoder.blocks.27.mlp.0.weight False
# encoder.blocks.27.mlp.0.bias False
# encoder.blocks.27.mlp.2.weight False
# encoder.blocks.27.mlp.2.bias False
# encoder.blocks.27.mlp_ln.weight False
# encoder.blocks.27.mlp_ln.bias False
# encoder.blocks.28.attn.query.weight False
# encoder.blocks.28.attn.query.bias True
# encoder.blocks.28.attn.query.lora_A True
# encoder.blocks.28.attn.query.lora_B True
# encoder.blocks.28.attn.key.weight False
# encoder.blocks.28.attn.value.weight False
# encoder.blocks.28.attn.value.bias True
# encoder.blocks.28.attn.value.lora_A True
# encoder.blocks.28.attn.value.lora_B True
# encoder.blocks.28.attn.out.weight False
# encoder.blocks.28.attn.out.bias False
# encoder.blocks.28.attn_ln.weight False
# encoder.blocks.28.attn_ln.bias False
# encoder.blocks.28.mlp.0.weight False
# encoder.blocks.28.mlp.0.bias False
# encoder.blocks.28.mlp.2.weight False
# encoder.blocks.28.mlp.2.bias False
# encoder.blocks.28.mlp_ln.weight False
# encoder.blocks.28.mlp_ln.bias False
# encoder.blocks.29.attn.query.weight False
# encoder.blocks.29.attn.query.bias True
# encoder.blocks.29.attn.query.lora_A True
# encoder.blocks.29.attn.query.lora_B True
# encoder.blocks.29.attn.key.weight False
# encoder.blocks.29.attn.value.weight False
# encoder.blocks.29.attn.value.bias True
# encoder.blocks.29.attn.value.lora_A True
# encoder.blocks.29.attn.value.lora_B True
# encoder.blocks.29.attn.out.weight False
# encoder.blocks.29.attn.out.bias False
# encoder.blocks.29.attn_ln.weight False
# encoder.blocks.29.attn_ln.bias False
# encoder.blocks.29.mlp.0.weight False
# encoder.blocks.29.mlp.0.bias False
# encoder.blocks.29.mlp.2.weight False
# encoder.blocks.29.mlp.2.bias False
# encoder.blocks.29.mlp_ln.weight False
# encoder.blocks.29.mlp_ln.bias False
# encoder.blocks.30.attn.query.weight False
# encoder.blocks.30.attn.query.bias True
# encoder.blocks.30.attn.query.lora_A True
# encoder.blocks.30.attn.query.lora_B True
# encoder.blocks.30.attn.key.weight False
# encoder.blocks.30.attn.value.weight False
# encoder.blocks.30.attn.value.bias True
# encoder.blocks.30.attn.value.lora_A True
# encoder.blocks.30.attn.value.lora_B True
# encoder.blocks.30.attn.out.weight False
# encoder.blocks.30.attn.out.bias False
# encoder.blocks.30.attn_ln.weight False
# encoder.blocks.30.attn_ln.bias False
# encoder.blocks.30.mlp.0.weight False
# encoder.blocks.30.mlp.0.bias False
# encoder.blocks.30.mlp.2.weight False
# encoder.blocks.30.mlp.2.bias False
# encoder.blocks.30.mlp_ln.weight False
# encoder.blocks.30.mlp_ln.bias False
# encoder.blocks.31.attn.query.weight False
# encoder.blocks.31.attn.query.bias True
# encoder.blocks.31.attn.query.lora_A True
# encoder.blocks.31.attn.query.lora_B True
# encoder.blocks.31.attn.key.weight False
# encoder.blocks.31.attn.value.weight False
# encoder.blocks.31.attn.value.bias True
# encoder.blocks.31.attn.value.lora_A True
# encoder.blocks.31.attn.value.lora_B True
# encoder.blocks.31.attn.out.weight False
# encoder.blocks.31.attn.out.bias False
# encoder.blocks.31.attn_ln.weight False
# encoder.blocks.31.attn_ln.bias False
# encoder.blocks.31.mlp.0.weight False
# encoder.blocks.31.mlp.0.bias False
# encoder.blocks.31.mlp.2.weight False
# encoder.blocks.31.mlp.2.bias False
# encoder.blocks.31.mlp_ln.weight False
# encoder.blocks.31.mlp_ln.bias False
# encoder.ln_post.weight False
# encoder.ln_post.bias False
# decoder.positional_embedding False
# decoder.token_embedding.weight False
# decoder.blocks.0.attn.query.weight False
# decoder.blocks.0.attn.query.bias True
# decoder.blocks.0.attn.query.lora_A True
# decoder.blocks.0.attn.query.lora_B True
# decoder.blocks.0.attn.key.weight False
# decoder.blocks.0.attn.value.weight False
# decoder.blocks.0.attn.value.bias True
# decoder.blocks.0.attn.value.lora_A True
# decoder.blocks.0.attn.value.lora_B True
# decoder.blocks.0.attn.out.weight False
# decoder.blocks.0.attn.out.bias False
# decoder.blocks.0.attn_ln.weight False
# decoder.blocks.0.attn_ln.bias False
# decoder.blocks.0.cross_attn.query.weight False
# decoder.blocks.0.cross_attn.query.bias True
# decoder.blocks.0.cross_attn.query.lora_A True
# decoder.blocks.0.cross_attn.query.lora_B True
# decoder.blocks.0.cross_attn.key.weight False
# decoder.blocks.0.cross_attn.value.weight False
# decoder.blocks.0.cross_attn.value.bias True
# decoder.blocks.0.cross_attn.value.lora_A True
# decoder.blocks.0.cross_attn.value.lora_B True
# decoder.blocks.0.cross_attn.out.weight False
# decoder.blocks.0.cross_attn.out.bias False
# decoder.blocks.0.cross_attn_ln.weight False
# decoder.blocks.0.cross_attn_ln.bias False
# decoder.blocks.0.mlp.0.weight False
# decoder.blocks.0.mlp.0.bias False
# decoder.blocks.0.mlp.2.weight False
# decoder.blocks.0.mlp.2.bias False
# decoder.blocks.0.mlp_ln.weight False
# decoder.blocks.0.mlp_ln.bias False
# decoder.blocks.1.attn.query.weight False
# decoder.blocks.1.attn.query.bias True
# decoder.blocks.1.attn.query.lora_A True
# decoder.blocks.1.attn.query.lora_B True
# decoder.blocks.1.attn.key.weight False
# decoder.blocks.1.attn.value.weight False
# decoder.blocks.1.attn.value.bias True
# decoder.blocks.1.attn.value.lora_A True
# decoder.blocks.1.attn.value.lora_B True
# decoder.blocks.1.attn.out.weight False
# decoder.blocks.1.attn.out.bias False
# decoder.blocks.1.attn_ln.weight False
# decoder.blocks.1.attn_ln.bias False
# decoder.blocks.1.cross_attn.query.weight False
# decoder.blocks.1.cross_attn.query.bias True
# decoder.blocks.1.cross_attn.query.lora_A True
# decoder.blocks.1.cross_attn.query.lora_B True
# decoder.blocks.1.cross_attn.key.weight False
# decoder.blocks.1.cross_attn.value.weight False
# decoder.blocks.1.cross_attn.value.bias True
# decoder.blocks.1.cross_attn.value.lora_A True
# decoder.blocks.1.cross_attn.value.lora_B True
# decoder.blocks.1.cross_attn.out.weight False
# decoder.blocks.1.cross_attn.out.bias False
# decoder.blocks.1.cross_attn_ln.weight False
# decoder.blocks.1.cross_attn_ln.bias False
# decoder.blocks.1.mlp.0.weight False
# decoder.blocks.1.mlp.0.bias False
# decoder.blocks.1.mlp.2.weight False
# decoder.blocks.1.mlp.2.bias False
# decoder.blocks.1.mlp_ln.weight False
# decoder.blocks.1.mlp_ln.bias False
# decoder.blocks.2.attn.query.weight False
# decoder.blocks.2.attn.query.bias True
# decoder.blocks.2.attn.query.lora_A True
# decoder.blocks.2.attn.query.lora_B True
# decoder.blocks.2.attn.key.weight False
# decoder.blocks.2.attn.value.weight False
# decoder.blocks.2.attn.value.bias True
# decoder.blocks.2.attn.value.lora_A True
# decoder.blocks.2.attn.value.lora_B True
# decoder.blocks.2.attn.out.weight False
# decoder.blocks.2.attn.out.bias False
# decoder.blocks.2.attn_ln.weight False
# decoder.blocks.2.attn_ln.bias False
# decoder.blocks.2.cross_attn.query.weight False
# decoder.blocks.2.cross_attn.query.bias True
# decoder.blocks.2.cross_attn.query.lora_A True
# decoder.blocks.2.cross_attn.query.lora_B True
# decoder.blocks.2.cross_attn.key.weight False
# decoder.blocks.2.cross_attn.value.weight False
# decoder.blocks.2.cross_attn.value.bias True
# decoder.blocks.2.cross_attn.value.lora_A True
# decoder.blocks.2.cross_attn.value.lora_B True
# decoder.blocks.2.cross_attn.out.weight False
# decoder.blocks.2.cross_attn.out.bias False
# decoder.blocks.2.cross_attn_ln.weight False
# decoder.blocks.2.cross_attn_ln.bias False
# decoder.blocks.2.mlp.0.weight False
# decoder.blocks.2.mlp.0.bias False
# decoder.blocks.2.mlp.2.weight False
# decoder.blocks.2.mlp.2.bias False
# decoder.blocks.2.mlp_ln.weight False
# decoder.blocks.2.mlp_ln.bias False
# decoder.blocks.3.attn.query.weight False
# decoder.blocks.3.attn.query.bias True
# decoder.blocks.3.attn.query.lora_A True
# decoder.blocks.3.attn.query.lora_B True
# decoder.blocks.3.attn.key.weight False
# decoder.blocks.3.attn.value.weight False
# decoder.blocks.3.attn.value.bias True
# decoder.blocks.3.attn.value.lora_A True
# decoder.blocks.3.attn.value.lora_B True
# decoder.blocks.3.attn.out.weight False
# decoder.blocks.3.attn.out.bias False
# decoder.blocks.3.attn_ln.weight False
# decoder.blocks.3.attn_ln.bias False
# decoder.blocks.3.cross_attn.query.weight False
# decoder.blocks.3.cross_attn.query.bias True
# decoder.blocks.3.cross_attn.query.lora_A True
# decoder.blocks.3.cross_attn.query.lora_B True
# decoder.blocks.3.cross_attn.key.weight False
# decoder.blocks.3.cross_attn.value.weight False
# decoder.blocks.3.cross_attn.value.bias True
# decoder.blocks.3.cross_attn.value.lora_A True
# decoder.blocks.3.cross_attn.value.lora_B True
# decoder.blocks.3.cross_attn.out.weight False
# decoder.blocks.3.cross_attn.out.bias False
# decoder.blocks.3.cross_attn_ln.weight False
# decoder.blocks.3.cross_attn_ln.bias False
# decoder.blocks.3.mlp.0.weight False
# decoder.blocks.3.mlp.0.bias False
# decoder.blocks.3.mlp.2.weight False
# decoder.blocks.3.mlp.2.bias False
# decoder.blocks.3.mlp_ln.weight False
# decoder.blocks.3.mlp_ln.bias False
# decoder.blocks.4.attn.query.weight False
# decoder.blocks.4.attn.query.bias True
# decoder.blocks.4.attn.query.lora_A True
# decoder.blocks.4.attn.query.lora_B True
# decoder.blocks.4.attn.key.weight False
# decoder.blocks.4.attn.value.weight False
# decoder.blocks.4.attn.value.bias True
# decoder.blocks.4.attn.value.lora_A True
# decoder.blocks.4.attn.value.lora_B True
# decoder.blocks.4.attn.out.weight False
# decoder.blocks.4.attn.out.bias False
# decoder.blocks.4.attn_ln.weight False
# decoder.blocks.4.attn_ln.bias False
# decoder.blocks.4.cross_attn.query.weight False
# decoder.blocks.4.cross_attn.query.bias True
# decoder.blocks.4.cross_attn.query.lora_A True
# decoder.blocks.4.cross_attn.query.lora_B True
# decoder.blocks.4.cross_attn.key.weight False
# decoder.blocks.4.cross_attn.value.weight False
# decoder.blocks.4.cross_attn.value.bias True
# decoder.blocks.4.cross_attn.value.lora_A True
# decoder.blocks.4.cross_attn.value.lora_B True
# decoder.blocks.4.cross_attn.out.weight False
# decoder.blocks.4.cross_attn.out.bias False
# decoder.blocks.4.cross_attn_ln.weight False
# decoder.blocks.4.cross_attn_ln.bias False
# decoder.blocks.4.mlp.0.weight False
# decoder.blocks.4.mlp.0.bias False
# decoder.blocks.4.mlp.2.weight False
# decoder.blocks.4.mlp.2.bias False
# decoder.blocks.4.mlp_ln.weight False
# decoder.blocks.4.mlp_ln.bias False
# decoder.blocks.5.attn.query.weight False
# decoder.blocks.5.attn.query.bias True
# decoder.blocks.5.attn.query.lora_A True
# decoder.blocks.5.attn.query.lora_B True
# decoder.blocks.5.attn.key.weight False
# decoder.blocks.5.attn.value.weight False
# decoder.blocks.5.attn.value.bias True
# decoder.blocks.5.attn.value.lora_A True
# decoder.blocks.5.attn.value.lora_B True
# decoder.blocks.5.attn.out.weight False
# decoder.blocks.5.attn.out.bias False
# decoder.blocks.5.attn_ln.weight False
# decoder.blocks.5.attn_ln.bias False
# decoder.blocks.5.cross_attn.query.weight False
# decoder.blocks.5.cross_attn.query.bias True
# decoder.blocks.5.cross_attn.query.lora_A True
# decoder.blocks.5.cross_attn.query.lora_B True
# decoder.blocks.5.cross_attn.key.weight False
# decoder.blocks.5.cross_attn.value.weight False
# decoder.blocks.5.cross_attn.value.bias True
# decoder.blocks.5.cross_attn.value.lora_A True
# decoder.blocks.5.cross_attn.value.lora_B True
# decoder.blocks.5.cross_attn.out.weight False
# decoder.blocks.5.cross_attn.out.bias False
# decoder.blocks.5.cross_attn_ln.weight False
# decoder.blocks.5.cross_attn_ln.bias False
# decoder.blocks.5.mlp.0.weight False
# decoder.blocks.5.mlp.0.bias False
# decoder.blocks.5.mlp.2.weight False
# decoder.blocks.5.mlp.2.bias False
# decoder.blocks.5.mlp_ln.weight False
# decoder.blocks.5.mlp_ln.bias False
# decoder.blocks.6.attn.query.weight False
# decoder.blocks.6.attn.query.bias True
# decoder.blocks.6.attn.query.lora_A True
# decoder.blocks.6.attn.query.lora_B True
# decoder.blocks.6.attn.key.weight False
# decoder.blocks.6.attn.value.weight False
# decoder.blocks.6.attn.value.bias True
# decoder.blocks.6.attn.value.lora_A True
# decoder.blocks.6.attn.value.lora_B True
# decoder.blocks.6.attn.out.weight False
# decoder.blocks.6.attn.out.bias False
# decoder.blocks.6.attn_ln.weight False
# decoder.blocks.6.attn_ln.bias False
# decoder.blocks.6.cross_attn.query.weight False
# decoder.blocks.6.cross_attn.query.bias True
# decoder.blocks.6.cross_attn.query.lora_A True
# decoder.blocks.6.cross_attn.query.lora_B True
# decoder.blocks.6.cross_attn.key.weight False
# decoder.blocks.6.cross_attn.value.weight False
# decoder.blocks.6.cross_attn.value.bias True
# decoder.blocks.6.cross_attn.value.lora_A True
# decoder.blocks.6.cross_attn.value.lora_B True
# decoder.blocks.6.cross_attn.out.weight False
# decoder.blocks.6.cross_attn.out.bias False
# decoder.blocks.6.cross_attn_ln.weight False
# decoder.blocks.6.cross_attn_ln.bias False
# decoder.blocks.6.mlp.0.weight False
# decoder.blocks.6.mlp.0.bias False
# decoder.blocks.6.mlp.2.weight False
# decoder.blocks.6.mlp.2.bias False
# decoder.blocks.6.mlp_ln.weight False
# decoder.blocks.6.mlp_ln.bias False
# decoder.blocks.7.attn.query.weight False
# decoder.blocks.7.attn.query.bias True
# decoder.blocks.7.attn.query.lora_A True
# decoder.blocks.7.attn.query.lora_B True
# decoder.blocks.7.attn.key.weight False
# decoder.blocks.7.attn.value.weight False
# decoder.blocks.7.attn.value.bias True
# decoder.blocks.7.attn.value.lora_A True
# decoder.blocks.7.attn.value.lora_B True
# decoder.blocks.7.attn.out.weight False
# decoder.blocks.7.attn.out.bias False
# decoder.blocks.7.attn_ln.weight False
# decoder.blocks.7.attn_ln.bias False
# decoder.blocks.7.cross_attn.query.weight False
# decoder.blocks.7.cross_attn.query.bias True
# decoder.blocks.7.cross_attn.query.lora_A True
# decoder.blocks.7.cross_attn.query.lora_B True
# decoder.blocks.7.cross_attn.key.weight False
# decoder.blocks.7.cross_attn.value.weight False
# decoder.blocks.7.cross_attn.value.bias True
# decoder.blocks.7.cross_attn.value.lora_A True
# decoder.blocks.7.cross_attn.value.lora_B True
# decoder.blocks.7.cross_attn.out.weight False
# decoder.blocks.7.cross_attn.out.bias False
# decoder.blocks.7.cross_attn_ln.weight False
# decoder.blocks.7.cross_attn_ln.bias False
# decoder.blocks.7.mlp.0.weight False
# decoder.blocks.7.mlp.0.bias False
# decoder.blocks.7.mlp.2.weight False
# decoder.blocks.7.mlp.2.bias False
# decoder.blocks.7.mlp_ln.weight False
# decoder.blocks.7.mlp_ln.bias False
# decoder.blocks.8.attn.query.weight False
# decoder.blocks.8.attn.query.bias True
# decoder.blocks.8.attn.query.lora_A True
# decoder.blocks.8.attn.query.lora_B True
# decoder.blocks.8.attn.key.weight False
# decoder.blocks.8.attn.value.weight False
# decoder.blocks.8.attn.value.bias True
# decoder.blocks.8.attn.value.lora_A True
# decoder.blocks.8.attn.value.lora_B True
# decoder.blocks.8.attn.out.weight False
# decoder.blocks.8.attn.out.bias False
# decoder.blocks.8.attn_ln.weight False
# decoder.blocks.8.attn_ln.bias False
# decoder.blocks.8.cross_attn.query.weight False
# decoder.blocks.8.cross_attn.query.bias True
# decoder.blocks.8.cross_attn.query.lora_A True
# decoder.blocks.8.cross_attn.query.lora_B True
# decoder.blocks.8.cross_attn.key.weight False
# decoder.blocks.8.cross_attn.value.weight False
# decoder.blocks.8.cross_attn.value.bias True
# decoder.blocks.8.cross_attn.value.lora_A True
# decoder.blocks.8.cross_attn.value.lora_B True
# decoder.blocks.8.cross_attn.out.weight False
# decoder.blocks.8.cross_attn.out.bias False
# decoder.blocks.8.cross_attn_ln.weight False
# decoder.blocks.8.cross_attn_ln.bias False
# decoder.blocks.8.mlp.0.weight False
# decoder.blocks.8.mlp.0.bias False
# decoder.blocks.8.mlp.2.weight False
# decoder.blocks.8.mlp.2.bias False
# decoder.blocks.8.mlp_ln.weight False
# decoder.blocks.8.mlp_ln.bias False
# decoder.blocks.9.attn.query.weight False
# decoder.blocks.9.attn.query.bias True
# decoder.blocks.9.attn.query.lora_A True
# decoder.blocks.9.attn.query.lora_B True
# decoder.blocks.9.attn.key.weight False
# decoder.blocks.9.attn.value.weight False
# decoder.blocks.9.attn.value.bias True
# decoder.blocks.9.attn.value.lora_A True
# decoder.blocks.9.attn.value.lora_B True
# decoder.blocks.9.attn.out.weight False
# decoder.blocks.9.attn.out.bias False
# decoder.blocks.9.attn_ln.weight False
# decoder.blocks.9.attn_ln.bias False
# decoder.blocks.9.cross_attn.query.weight False
# decoder.blocks.9.cross_attn.query.bias True
# decoder.blocks.9.cross_attn.query.lora_A True
# decoder.blocks.9.cross_attn.query.lora_B True
# decoder.blocks.9.cross_attn.key.weight False
# decoder.blocks.9.cross_attn.value.weight False
# decoder.blocks.9.cross_attn.value.bias True
# decoder.blocks.9.cross_attn.value.lora_A True
# decoder.blocks.9.cross_attn.value.lora_B True
# decoder.blocks.9.cross_attn.out.weight False
# decoder.blocks.9.cross_attn.out.bias False
# decoder.blocks.9.cross_attn_ln.weight False
# decoder.blocks.9.cross_attn_ln.bias False
# decoder.blocks.9.mlp.0.weight False
# decoder.blocks.9.mlp.0.bias False
# decoder.blocks.9.mlp.2.weight False
# decoder.blocks.9.mlp.2.bias False
# decoder.blocks.9.mlp_ln.weight False
# decoder.blocks.9.mlp_ln.bias False
# decoder.blocks.10.attn.query.weight False
# decoder.blocks.10.attn.query.bias True
# decoder.blocks.10.attn.query.lora_A True
# decoder.blocks.10.attn.query.lora_B True
# decoder.blocks.10.attn.key.weight False
# decoder.blocks.10.attn.value.weight False
# decoder.blocks.10.attn.value.bias True
# decoder.blocks.10.attn.value.lora_A True
# decoder.blocks.10.attn.value.lora_B True
# decoder.blocks.10.attn.out.weight False
# decoder.blocks.10.attn.out.bias False
# decoder.blocks.10.attn_ln.weight False
# decoder.blocks.10.attn_ln.bias False
# decoder.blocks.10.cross_attn.query.weight False
# decoder.blocks.10.cross_attn.query.bias True
# decoder.blocks.10.cross_attn.query.lora_A True
# decoder.blocks.10.cross_attn.query.lora_B True
# decoder.blocks.10.cross_attn.key.weight False
# decoder.blocks.10.cross_attn.value.weight False
# decoder.blocks.10.cross_attn.value.bias True
# decoder.blocks.10.cross_attn.value.lora_A True
# decoder.blocks.10.cross_attn.value.lora_B True
# decoder.blocks.10.cross_attn.out.weight False
# decoder.blocks.10.cross_attn.out.bias False
# decoder.blocks.10.cross_attn_ln.weight False
# decoder.blocks.10.cross_attn_ln.bias False
# decoder.blocks.10.mlp.0.weight False
# decoder.blocks.10.mlp.0.bias False
# decoder.blocks.10.mlp.2.weight False
# decoder.blocks.10.mlp.2.bias False
# decoder.blocks.10.mlp_ln.weight False
# decoder.blocks.10.mlp_ln.bias False
# decoder.blocks.11.attn.query.weight False
# decoder.blocks.11.attn.query.bias True
# decoder.blocks.11.attn.query.lora_A True
# decoder.blocks.11.attn.query.lora_B True
# decoder.blocks.11.attn.key.weight False
# decoder.blocks.11.attn.value.weight False
# decoder.blocks.11.attn.value.bias True
# decoder.blocks.11.attn.value.lora_A True
# decoder.blocks.11.attn.value.lora_B True
# decoder.blocks.11.attn.out.weight False
# decoder.blocks.11.attn.out.bias False
# decoder.blocks.11.attn_ln.weight False
# decoder.blocks.11.attn_ln.bias False
# decoder.blocks.11.cross_attn.query.weight False
# decoder.blocks.11.cross_attn.query.bias True
# decoder.blocks.11.cross_attn.query.lora_A True
# decoder.blocks.11.cross_attn.query.lora_B True
# decoder.blocks.11.cross_attn.key.weight False
# decoder.blocks.11.cross_attn.value.weight False
# decoder.blocks.11.cross_attn.value.bias True
# decoder.blocks.11.cross_attn.value.lora_A True
# decoder.blocks.11.cross_attn.value.lora_B True
# decoder.blocks.11.cross_attn.out.weight False
# decoder.blocks.11.cross_attn.out.bias False
# decoder.blocks.11.cross_attn_ln.weight False
# decoder.blocks.11.cross_attn_ln.bias False
# decoder.blocks.11.mlp.0.weight False
# decoder.blocks.11.mlp.0.bias False
# decoder.blocks.11.mlp.2.weight False
# decoder.blocks.11.mlp.2.bias False
# decoder.blocks.11.mlp_ln.weight False
# decoder.blocks.11.mlp_ln.bias False
# decoder.blocks.12.attn.query.weight False
# decoder.blocks.12.attn.query.bias True
# decoder.blocks.12.attn.query.lora_A True
# decoder.blocks.12.attn.query.lora_B True
# decoder.blocks.12.attn.key.weight False
# decoder.blocks.12.attn.value.weight False
# decoder.blocks.12.attn.value.bias True
# decoder.blocks.12.attn.value.lora_A True
# decoder.blocks.12.attn.value.lora_B True
# decoder.blocks.12.attn.out.weight False
# decoder.blocks.12.attn.out.bias False
# decoder.blocks.12.attn_ln.weight False
# decoder.blocks.12.attn_ln.bias False
# decoder.blocks.12.cross_attn.query.weight False
# decoder.blocks.12.cross_attn.query.bias True
# decoder.blocks.12.cross_attn.query.lora_A True
# decoder.blocks.12.cross_attn.query.lora_B True
# decoder.blocks.12.cross_attn.key.weight False
# decoder.blocks.12.cross_attn.value.weight False
# decoder.blocks.12.cross_attn.value.bias True
# decoder.blocks.12.cross_attn.value.lora_A True
# decoder.blocks.12.cross_attn.value.lora_B True
# decoder.blocks.12.cross_attn.out.weight False
# decoder.blocks.12.cross_attn.out.bias False
# decoder.blocks.12.cross_attn_ln.weight False
# decoder.blocks.12.cross_attn_ln.bias False
# decoder.blocks.12.mlp.0.weight False
# decoder.blocks.12.mlp.0.bias False
# decoder.blocks.12.mlp.2.weight False
# decoder.blocks.12.mlp.2.bias False
# decoder.blocks.12.mlp_ln.weight False
# decoder.blocks.12.mlp_ln.bias False
# decoder.blocks.13.attn.query.weight False
# decoder.blocks.13.attn.query.bias True
# decoder.blocks.13.attn.query.lora_A True
# decoder.blocks.13.attn.query.lora_B True
# decoder.blocks.13.attn.key.weight False
# decoder.blocks.13.attn.value.weight False
# decoder.blocks.13.attn.value.bias True
# decoder.blocks.13.attn.value.lora_A True
# decoder.blocks.13.attn.value.lora_B True
# decoder.blocks.13.attn.out.weight False
# decoder.blocks.13.attn.out.bias False
# decoder.blocks.13.attn_ln.weight False
# decoder.blocks.13.attn_ln.bias False
# decoder.blocks.13.cross_attn.query.weight False
# decoder.blocks.13.cross_attn.query.bias True
# decoder.blocks.13.cross_attn.query.lora_A True
# decoder.blocks.13.cross_attn.query.lora_B True
# decoder.blocks.13.cross_attn.key.weight False
# decoder.blocks.13.cross_attn.value.weight False
# decoder.blocks.13.cross_attn.value.bias True
# decoder.blocks.13.cross_attn.value.lora_A True
# decoder.blocks.13.cross_attn.value.lora_B True
# decoder.blocks.13.cross_attn.out.weight False
# decoder.blocks.13.cross_attn.out.bias False
# decoder.blocks.13.cross_attn_ln.weight False
# decoder.blocks.13.cross_attn_ln.bias False
# decoder.blocks.13.mlp.0.weight False
# decoder.blocks.13.mlp.0.bias False
# decoder.blocks.13.mlp.2.weight False
# decoder.blocks.13.mlp.2.bias False
# decoder.blocks.13.mlp_ln.weight False
# decoder.blocks.13.mlp_ln.bias False
# decoder.blocks.14.attn.query.weight False
# decoder.blocks.14.attn.query.bias True
# decoder.blocks.14.attn.query.lora_A True
# decoder.blocks.14.attn.query.lora_B True
# decoder.blocks.14.attn.key.weight False
# decoder.blocks.14.attn.value.weight False
# decoder.blocks.14.attn.value.bias True
# decoder.blocks.14.attn.value.lora_A True
# decoder.blocks.14.attn.value.lora_B True
# decoder.blocks.14.attn.out.weight False
# decoder.blocks.14.attn.out.bias False
# decoder.blocks.14.attn_ln.weight False
# decoder.blocks.14.attn_ln.bias False
# decoder.blocks.14.cross_attn.query.weight False
# decoder.blocks.14.cross_attn.query.bias True
# decoder.blocks.14.cross_attn.query.lora_A True
# decoder.blocks.14.cross_attn.query.lora_B True
# decoder.blocks.14.cross_attn.key.weight False
# decoder.blocks.14.cross_attn.value.weight False
# decoder.blocks.14.cross_attn.value.bias True
# decoder.blocks.14.cross_attn.value.lora_A True
# decoder.blocks.14.cross_attn.value.lora_B True
# decoder.blocks.14.cross_attn.out.weight False
# decoder.blocks.14.cross_attn.out.bias False
# decoder.blocks.14.cross_attn_ln.weight False
# decoder.blocks.14.cross_attn_ln.bias False
# decoder.blocks.14.mlp.0.weight False
# decoder.blocks.14.mlp.0.bias False
# decoder.blocks.14.mlp.2.weight False
# decoder.blocks.14.mlp.2.bias False
# decoder.blocks.14.mlp_ln.weight False
# decoder.blocks.14.mlp_ln.bias False
# decoder.blocks.15.attn.query.weight False
# decoder.blocks.15.attn.query.bias True
# decoder.blocks.15.attn.query.lora_A True
# decoder.blocks.15.attn.query.lora_B True
# decoder.blocks.15.attn.key.weight False
# decoder.blocks.15.attn.value.weight False
# decoder.blocks.15.attn.value.bias True
# decoder.blocks.15.attn.value.lora_A True
# decoder.blocks.15.attn.value.lora_B True
# decoder.blocks.15.attn.out.weight False
# decoder.blocks.15.attn.out.bias False
# decoder.blocks.15.attn_ln.weight False
# decoder.blocks.15.attn_ln.bias False
# decoder.blocks.15.cross_attn.query.weight False
# decoder.blocks.15.cross_attn.query.bias True
# decoder.blocks.15.cross_attn.query.lora_A True
# decoder.blocks.15.cross_attn.query.lora_B True
# decoder.blocks.15.cross_attn.key.weight False
# decoder.blocks.15.cross_attn.value.weight False
# decoder.blocks.15.cross_attn.value.bias True
# decoder.blocks.15.cross_attn.value.lora_A True
# decoder.blocks.15.cross_attn.value.lora_B True
# decoder.blocks.15.cross_attn.out.weight False
# decoder.blocks.15.cross_attn.out.bias False
# decoder.blocks.15.cross_attn_ln.weight False
# decoder.blocks.15.cross_attn_ln.bias False
# decoder.blocks.15.mlp.0.weight False
# decoder.blocks.15.mlp.0.bias False
# decoder.blocks.15.mlp.2.weight False
# decoder.blocks.15.mlp.2.bias False
# decoder.blocks.15.mlp_ln.weight False
# decoder.blocks.15.mlp_ln.bias False
# decoder.blocks.16.attn.query.weight False
# decoder.blocks.16.attn.query.bias True
# decoder.blocks.16.attn.query.lora_A True
# decoder.blocks.16.attn.query.lora_B True
# decoder.blocks.16.attn.key.weight False
# decoder.blocks.16.attn.value.weight False
# decoder.blocks.16.attn.value.bias True
# decoder.blocks.16.attn.value.lora_A True
# decoder.blocks.16.attn.value.lora_B True
# decoder.blocks.16.attn.out.weight False
# decoder.blocks.16.attn.out.bias False
# decoder.blocks.16.attn_ln.weight False
# decoder.blocks.16.attn_ln.bias False
# decoder.blocks.16.cross_attn.query.weight False
# decoder.blocks.16.cross_attn.query.bias True
# decoder.blocks.16.cross_attn.query.lora_A True
# decoder.blocks.16.cross_attn.query.lora_B True
# decoder.blocks.16.cross_attn.key.weight False
# decoder.blocks.16.cross_attn.value.weight False
# decoder.blocks.16.cross_attn.value.bias True
# decoder.blocks.16.cross_attn.value.lora_A True
# decoder.blocks.16.cross_attn.value.lora_B True
# decoder.blocks.16.cross_attn.out.weight False
# decoder.blocks.16.cross_attn.out.bias False
# decoder.blocks.16.cross_attn_ln.weight False
# decoder.blocks.16.cross_attn_ln.bias False
# decoder.blocks.16.mlp.0.weight False
# decoder.blocks.16.mlp.0.bias False
# decoder.blocks.16.mlp.2.weight False
# decoder.blocks.16.mlp.2.bias False
# decoder.blocks.16.mlp_ln.weight False
# decoder.blocks.16.mlp_ln.bias False
# decoder.blocks.17.attn.query.weight False
# decoder.blocks.17.attn.query.bias True
# decoder.blocks.17.attn.query.lora_A True
# decoder.blocks.17.attn.query.lora_B True
# decoder.blocks.17.attn.key.weight False
# decoder.blocks.17.attn.value.weight False
# decoder.blocks.17.attn.value.bias True
# decoder.blocks.17.attn.value.lora_A True
# decoder.blocks.17.attn.value.lora_B True
# decoder.blocks.17.attn.out.weight False
# decoder.blocks.17.attn.out.bias False
# decoder.blocks.17.attn_ln.weight False
# decoder.blocks.17.attn_ln.bias False
# decoder.blocks.17.cross_attn.query.weight False
# decoder.blocks.17.cross_attn.query.bias True
# decoder.blocks.17.cross_attn.query.lora_A True
# decoder.blocks.17.cross_attn.query.lora_B True
# decoder.blocks.17.cross_attn.key.weight False
# decoder.blocks.17.cross_attn.value.weight False
# decoder.blocks.17.cross_attn.value.bias True
# decoder.blocks.17.cross_attn.value.lora_A True
# decoder.blocks.17.cross_attn.value.lora_B True
# decoder.blocks.17.cross_attn.out.weight False
# decoder.blocks.17.cross_attn.out.bias False
# decoder.blocks.17.cross_attn_ln.weight False
# decoder.blocks.17.cross_attn_ln.bias False
# decoder.blocks.17.mlp.0.weight False
# decoder.blocks.17.mlp.0.bias False
# decoder.blocks.17.mlp.2.weight False
# decoder.blocks.17.mlp.2.bias False
# decoder.blocks.17.mlp_ln.weight False
# decoder.blocks.17.mlp_ln.bias False
# decoder.blocks.18.attn.query.weight False
# decoder.blocks.18.attn.query.bias True
# decoder.blocks.18.attn.query.lora_A True
# decoder.blocks.18.attn.query.lora_B True
# decoder.blocks.18.attn.key.weight False
# decoder.blocks.18.attn.value.weight False
# decoder.blocks.18.attn.value.bias True
# decoder.blocks.18.attn.value.lora_A True
# decoder.blocks.18.attn.value.lora_B True
# decoder.blocks.18.attn.out.weight False
# decoder.blocks.18.attn.out.bias False
# decoder.blocks.18.attn_ln.weight False
# decoder.blocks.18.attn_ln.bias False
# decoder.blocks.18.cross_attn.query.weight False
# decoder.blocks.18.cross_attn.query.bias True
# ...
# decoder.blocks.20.attn.query.lora_A True
# decoder.blocks.20.attn.query.lora_B True
# decoder.blocks.20.attn.key.weight False
# decoder.blocks.20.attn.value.weight False
# decoder.blocks.20.attn.value.bias True
# decoder.blocks.20.attn.value.lora_A True
# decoder.blocks.20.attn.value.lora_B True
# decoder.blocks.20.attn.out.weight False
# decoder.blocks.20.attn.out.bias False
# decoder.blocks.20.attn_ln.weight False
# decoder.blocks.20.attn_ln.bias False
# decoder.blocks.20.cross_attn.query.weight False
# decoder.blocks.20.cross_attn.query.bias True
# decoder.blocks.20.cross_attn.query.lora_A True
# decoder.blocks.20.cross_attn.query.lora_B True
# decoder.blocks.20.cross_attn.key.weight False
# decoder.blocks.20.cross_attn.value.weight False
# decoder.blocks.20.cross_attn.value.bias True
# decoder.blocks.20.cross_attn.value.lora_A True
# decoder.blocks.20.cross_attn.value.lora_B True
# decoder.blocks.20.cross_attn.out.weight False
# decoder.blocks.20.cross_attn.out.bias False
# decoder.blocks.20.cross_attn_ln.weight False
# decoder.blocks.20.cross_attn_ln.bias False
# decoder.blocks.20.mlp.0.weight False
# decoder.blocks.20.mlp.0.bias False
# decoder.blocks.20.mlp.2.weight False
# decoder.blocks.20.mlp.2.bias False
# decoder.blocks.20.mlp_ln.weight False
# decoder.blocks.20.mlp_ln.bias False
# decoder.blocks.21.attn.query.weight False
# decoder.blocks.21.attn.query.bias True
# decoder.blocks.21.attn.query.lora_A True
# decoder.blocks.21.attn.query.lora_B True
# decoder.blocks.21.attn.key.weight False
# decoder.blocks.21.attn.value.weight False
# decoder.blocks.21.attn.value.bias True
# decoder.blocks.21.attn.value.lora_A True
# decoder.blocks.21.attn.value.lora_B True
# decoder.blocks.21.attn.out.weight False
# decoder.blocks.21.attn.out.bias False
# decoder.blocks.21.attn_ln.weight False
# decoder.blocks.21.attn_ln.bias False
# decoder.blocks.21.cross_attn.query.weight False
# decoder.blocks.21.cross_attn.query.bias True
# decoder.blocks.21.cross_attn.query.lora_A True
# decoder.blocks.21.cross_attn.query.lora_B True
# decoder.blocks.21.cross_attn.key.weight False
# decoder.blocks.21.cross_attn.value.weight False
# decoder.blocks.21.cross_attn.value.bias True
# decoder.blocks.21.cross_attn.value.lora_A True
# decoder.blocks.21.cross_attn.value.lora_B True
# decoder.blocks.21.cross_attn.out.weight False
# decoder.blocks.21.cross_attn.out.bias False
# decoder.blocks.21.cross_attn_ln.weight False
# decoder.blocks.21.cross_attn_ln.bias False
# decoder.blocks.21.mlp.0.weight False
# decoder.blocks.21.mlp.0.bias False
# decoder.blocks.21.mlp.2.weight False
# decoder.blocks.21.mlp.2.bias False
# decoder.blocks.21.mlp_ln.weight False
# decoder.blocks.21.mlp_ln.bias False
# decoder.blocks.22.attn.query.weight False
# decoder.blocks.22.attn.query.bias True
# decoder.blocks.22.attn.query.lora_A True
# decoder.blocks.22.attn.query.lora_B True
# decoder.blocks.22.attn.key.weight False
# decoder.blocks.22.attn.value.weight False
# decoder.blocks.22.attn.value.bias True
# decoder.blocks.22.attn.value.lora_A True
# decoder.blocks.22.attn.value.lora_B True
# decoder.blocks.22.attn.out.weight False
# decoder.blocks.22.attn.out.bias False
# decoder.blocks.22.attn_ln.weight False
# decoder.blocks.22.attn_ln.bias False
# decoder.blocks.22.cross_attn.query.weight False
# decoder.blocks.22.cross_attn.query.bias True
# decoder.blocks.22.cross_attn.query.lora_A True
# decoder.blocks.22.cross_attn.query.lora_B True
# decoder.blocks.22.cross_attn.key.weight False
# decoder.blocks.22.cross_attn.value.weight False
# decoder.blocks.22.cross_attn.value.bias True
# decoder.blocks.22.cross_attn.value.lora_A True
# decoder.blocks.22.cross_attn.value.lora_B True
# decoder.blocks.22.cross_attn.out.weight False
# decoder.blocks.22.cross_attn.out.bias False
# decoder.blocks.22.cross_attn_ln.weight False
# decoder.blocks.22.cross_attn_ln.bias False
# decoder.blocks.22.mlp.0.weight False
# decoder.blocks.22.mlp.0.bias False
# decoder.blocks.22.mlp.2.weight False
# decoder.blocks.22.mlp.2.bias False
# decoder.blocks.22.mlp_ln.weight False
# decoder.blocks.22.mlp_ln.bias False
# decoder.blocks.23.attn.query.weight False
# decoder.blocks.23.attn.query.bias True
# decoder.blocks.23.attn.query.lora_A True
# decoder.blocks.23.attn.query.lora_B True
# decoder.blocks.23.attn.key.weight False
# decoder.blocks.23.attn.value.weight False
# decoder.blocks.23.attn.value.bias True
# decoder.blocks.23.attn.value.lora_A True
# decoder.blocks.23.attn.value.lora_B True
# decoder.blocks.23.attn.out.weight False
# decoder.blocks.23.attn.out.bias False
# decoder.blocks.23.attn_ln.weight False
# decoder.blocks.23.attn_ln.bias False
# decoder.blocks.23.cross_attn.query.weight False
# decoder.blocks.23.cross_attn.query.bias True
# decoder.blocks.23.cross_attn.query.lora_A True
# decoder.blocks.23.cross_attn.query.lora_B True
# decoder.blocks.23.cross_attn.key.weight False
# decoder.blocks.23.cross_attn.value.weight False
# decoder.blocks.23.cross_attn.value.bias True
# decoder.blocks.23.cross_attn.value.lora_A True
# decoder.blocks.23.cross_attn.value.lora_B True
# decoder.blocks.23.cross_attn.out.weight False
# decoder.blocks.23.cross_attn.out.bias False
# decoder.blocks.23.cross_attn_ln.weight False
# decoder.blocks.23.cross_attn_ln.bias False
# decoder.blocks.23.mlp.0.weight False
# decoder.blocks.23.mlp.0.bias False
# decoder.blocks.23.mlp.2.weight False
# decoder.blocks.23.mlp.2.bias False
# decoder.blocks.23.mlp_ln.weight False
# decoder.blocks.23.mlp_ln.bias False
# decoder.blocks.24.attn.query.weight False
# decoder.blocks.24.attn.query.bias True
# decoder.blocks.24.attn.query.lora_A True
# decoder.blocks.24.attn.query.lora_B True
# decoder.blocks.24.attn.key.weight False
# decoder.blocks.24.attn.value.weight False
# decoder.blocks.24.attn.value.bias True
# decoder.blocks.24.attn.value.lora_A True
# decoder.blocks.24.attn.value.lora_B True
# decoder.blocks.24.attn.out.weight False
# decoder.blocks.24.attn.out.bias False
# decoder.blocks.24.attn_ln.weight False
# decoder.blocks.24.attn_ln.bias False
# decoder.blocks.24.cross_attn.query.weight False
# decoder.blocks.24.cross_attn.query.bias True
# decoder.blocks.24.cross_attn.query.lora_A True
# decoder.blocks.24.cross_attn.query.lora_B True
# decoder.blocks.24.cross_attn.key.weight False
# decoder.blocks.24.cross_attn.value.weight False
# decoder.blocks.24.cross_attn.value.bias True
# decoder.blocks.24.cross_attn.value.lora_A True
# decoder.blocks.24.cross_attn.value.lora_B True
# decoder.blocks.24.cross_attn.out.weight False
# decoder.blocks.24.cross_attn.out.bias False
# decoder.blocks.24.cross_attn_ln.weight False
# decoder.blocks.24.cross_attn_ln.bias False
# decoder.blocks.24.mlp.0.weight False
# decoder.blocks.24.mlp.0.bias False
# decoder.blocks.24.mlp.2.weight False
# decoder.blocks.24.mlp.2.bias False
# decoder.blocks.24.mlp_ln.weight False
# decoder.blocks.24.mlp_ln.bias False
# decoder.blocks.25.attn.query.weight False
# decoder.blocks.25.attn.query.bias True
# decoder.blocks.25.attn.query.lora_A True
# decoder.blocks.25.attn.query.lora_B True
# decoder.blocks.25.attn.key.weight False
# decoder.blocks.25.attn.value.weight False
# decoder.blocks.25.attn.value.bias True
# decoder.blocks.25.attn.value.lora_A True
# decoder.blocks.25.attn.value.lora_B True
# decoder.blocks.25.attn.out.weight False
# decoder.blocks.25.attn.out.bias False
# decoder.blocks.25.attn_ln.weight False
# decoder.blocks.25.attn_ln.bias False
# decoder.blocks.25.cross_attn.query.weight False
# decoder.blocks.25.cross_attn.query.bias True
# decoder.blocks.25.cross_attn.query.lora_A True
# decoder.blocks.25.cross_attn.query.lora_B True
# decoder.blocks.25.cross_attn.key.weight False
# decoder.blocks.25.cross_attn.value.weight False
# decoder.blocks.25.cross_attn.value.bias True
# decoder.blocks.25.cross_attn.value.lora_A True
# decoder.blocks.25.cross_attn.value.lora_B True
# decoder.blocks.25.cross_attn.out.weight False
# decoder.blocks.25.cross_attn.out.bias False
# decoder.blocks.25.cross_attn_ln.weight False
# decoder.blocks.25.cross_attn_ln.bias False
# decoder.blocks.25.mlp.0.weight False
# decoder.blocks.25.mlp.0.bias False
# decoder.blocks.25.mlp.2.weight False
# decoder.blocks.25.mlp.2.bias False
# decoder.blocks.25.mlp_ln.weight False
# decoder.blocks.25.mlp_ln.bias False
# decoder.blocks.26.attn.query.weight False
# decoder.blocks.26.attn.query.bias True
# decoder.blocks.26.attn.query.lora_A True
# decoder.blocks.26.attn.query.lora_B True
# decoder.blocks.26.attn.key.weight False
# decoder.blocks.26.attn.value.weight False
# decoder.blocks.26.attn.value.bias True
# decoder.blocks.26.attn.value.lora_A True
# decoder.blocks.26.attn.value.lora_B True
# decoder.blocks.26.attn.out.weight False
# decoder.blocks.26.attn.out.bias False
# decoder.blocks.26.attn_ln.weight False
# decoder.blocks.26.attn_ln.bias False
# decoder.blocks.26.cross_attn.query.weight False
# decoder.blocks.26.cross_attn.query.bias True
# decoder.blocks.26.cross_attn.query.lora_A True
# decoder.blocks.26.cross_attn.query.lora_B True
# decoder.blocks.26.cross_attn.key.weight False
# decoder.blocks.26.cross_attn.value.weight False
# decoder.blocks.26.cross_attn.value.bias True
# decoder.blocks.26.cross_attn.value.lora_A True
# decoder.blocks.26.cross_attn.value.lora_B True
# decoder.blocks.26.cross_attn.out.weight False
# decoder.blocks.26.cross_attn.out.bias False
# decoder.blocks.26.cross_attn_ln.weight False
# decoder.blocks.26.cross_attn_ln.bias False
# decoder.blocks.26.mlp.0.weight False
# decoder.blocks.26.mlp.0.bias False
# decoder.blocks.26.mlp.2.weight False
# decoder.blocks.26.mlp.2.bias False
# decoder.blocks.26.mlp_ln.weight False
# decoder.blocks.26.mlp_ln.bias False
# decoder.blocks.27.attn.query.weight False
# decoder.blocks.27.attn.query.bias True
# decoder.blocks.27.attn.query.lora_A True
# decoder.blocks.27.attn.query.lora_B True
# decoder.blocks.27.attn.key.weight False
# decoder.blocks.27.attn.value.weight False
# decoder.blocks.27.attn.value.bias True
# decoder.blocks.27.attn.value.lora_A True
# decoder.blocks.27.attn.value.lora_B True
# decoder.blocks.27.attn.out.weight False
# decoder.blocks.27.attn.out.bias False
# decoder.blocks.27.attn_ln.weight False
# decoder.blocks.27.attn_ln.bias False
# decoder.blocks.27.cross_attn.query.weight False
# decoder.blocks.27.cross_attn.query.bias True
# decoder.blocks.27.cross_attn.query.lora_A True
# decoder.blocks.27.cross_attn.query.lora_B True
# decoder.blocks.27.cross_attn.key.weight False
# decoder.blocks.27.cross_attn.value.weight False
# decoder.blocks.27.cross_attn.value.bias True
# decoder.blocks.27.cross_attn.value.lora_A True
# decoder.blocks.27.cross_attn.value.lora_B True
# decoder.blocks.27.cross_attn.out.weight False
# decoder.blocks.27.cross_attn.out.bias False
# decoder.blocks.27.cross_attn_ln.weight False
# decoder.blocks.27.cross_attn_ln.bias False
# decoder.blocks.27.mlp.0.weight False
# decoder.blocks.27.mlp.0.bias False
# decoder.blocks.27.mlp.2.weight False
# decoder.blocks.27.mlp.2.bias False
# decoder.blocks.27.mlp_ln.weight False
# decoder.blocks.27.mlp_ln.bias False
# decoder.blocks.28.attn.query.weight False
# decoder.blocks.28.attn.query.bias True
# decoder.blocks.28.attn.query.lora_A True
# decoder.blocks.28.attn.query.lora_B True
# decoder.blocks.28.attn.key.weight False
# decoder.blocks.28.attn.value.weight False
# decoder.blocks.28.attn.value.bias True
# decoder.blocks.28.attn.value.lora_A True
# decoder.blocks.28.attn.value.lora_B True
# decoder.blocks.28.attn.out.weight False
# decoder.blocks.28.attn.out.bias False
# decoder.blocks.28.attn_ln.weight False
# decoder.blocks.28.attn_ln.bias False
# decoder.blocks.28.cross_attn.query.weight False
# decoder.blocks.28.cross_attn.query.bias True
# decoder.blocks.28.cross_attn.query.lora_A True
# decoder.blocks.28.cross_attn.query.lora_B True
# decoder.blocks.28.cross_attn.key.weight False
# decoder.blocks.28.cross_attn.value.weight False
# decoder.blocks.28.cross_attn.value.bias True
# decoder.blocks.28.cross_attn.value.lora_A True
# decoder.blocks.28.cross_attn.value.lora_B True
# decoder.blocks.28.cross_attn.out.weight False
# decoder.blocks.28.cross_attn.out.bias False
# decoder.blocks.28.cross_attn_ln.weight False
# decoder.blocks.28.cross_attn_ln.bias False
# decoder.blocks.28.mlp.0.weight False
# decoder.blocks.28.mlp.0.bias False
# decoder.blocks.28.mlp.2.weight False
# decoder.blocks.28.mlp.2.bias False
# decoder.blocks.28.mlp_ln.weight False
# decoder.blocks.28.mlp_ln.bias False
# decoder.blocks.29.attn.query.weight False
# decoder.blocks.29.attn.query.bias True
# decoder.blocks.29.attn.query.lora_A True
# decoder.blocks.29.attn.query.lora_B True
# decoder.blocks.29.attn.key.weight False
# decoder.blocks.29.attn.value.weight False
# decoder.blocks.29.attn.value.bias True
# decoder.blocks.29.attn.value.lora_A True
# decoder.blocks.29.attn.value.lora_B True
# decoder.blocks.29.attn.out.weight False
# decoder.blocks.29.attn.out.bias False
# decoder.blocks.29.attn_ln.weight False
# decoder.blocks.29.attn_ln.bias False
# decoder.blocks.29.cross_attn.query.weight False
# decoder.blocks.29.cross_attn.query.bias True
# decoder.blocks.29.cross_attn.query.lora_A True
# decoder.blocks.29.cross_attn.query.lora_B True
# decoder.blocks.29.cross_attn.key.weight False
# decoder.blocks.29.cross_attn.value.weight False
# decoder.blocks.29.cross_attn.value.bias True
# decoder.blocks.29.cross_attn.value.lora_A True
# decoder.blocks.29.cross_attn.value.lora_B True
# decoder.blocks.29.cross_attn.out.weight False
# decoder.blocks.29.cross_attn.out.bias False
# decoder.blocks.29.cross_attn_ln.weight False
# decoder.blocks.29.cross_attn_ln.bias False
# decoder.blocks.29.mlp.0.weight False
# decoder.blocks.29.mlp.0.bias False
# decoder.blocks.29.mlp.2.weight False
# decoder.blocks.29.mlp.2.bias False
# decoder.blocks.29.mlp_ln.weight False
# decoder.blocks.29.mlp_ln.bias False
# decoder.blocks.30.attn.query.weight False
# decoder.blocks.30.attn.query.bias True
# decoder.blocks.30.attn.query.lora_A True
# decoder.blocks.30.attn.query.lora_B True
# decoder.blocks.30.attn.key.weight False
# decoder.blocks.30.attn.value.weight False
# decoder.blocks.30.attn.value.bias True
# decoder.blocks.30.attn.value.lora_A True
# decoder.blocks.30.attn.value.lora_B True
# decoder.blocks.30.attn.out.weight False
# decoder.blocks.30.attn.out.bias False
# decoder.blocks.30.attn_ln.weight False
# decoder.blocks.30.attn_ln.bias False
# decoder.blocks.30.cross_attn.query.weight False
# decoder.blocks.30.cross_attn.query.bias True
# decoder.blocks.30.cross_attn.query.lora_A True
# decoder.blocks.30.cross_attn.query.lora_B True
# decoder.blocks.30.cross_attn.key.weight False
# decoder.blocks.30.cross_attn.value.weight False
# decoder.blocks.30.cross_attn.value.bias True
# decoder.blocks.30.cross_attn.value.lora_A True
# decoder.blocks.30.cross_attn.value.lora_B True
# decoder.blocks.30.cross_attn.out.weight False
# decoder.blocks.30.cross_attn.out.bias False
# decoder.blocks.30.cross_attn_ln.weight False
# decoder.blocks.30.cross_attn_ln.bias False
# decoder.blocks.30.mlp.0.weight False
# decoder.blocks.30.mlp.0.bias False
# decoder.blocks.30.mlp.2.weight False
# decoder.blocks.30.mlp.2.bias False
# decoder.blocks.30.mlp_ln.weight False
# decoder.blocks.30.mlp_ln.bias False
# decoder.blocks.31.attn.query.weight False
# decoder.blocks.31.attn.query.bias True
# decoder.blocks.31.attn.query.lora_A True
# decoder.blocks.31.attn.query.lora_B True
# decoder.blocks.31.attn.key.weight False
# decoder.blocks.31.attn.value.weight False
# decoder.blocks.31.attn.value.bias True
# decoder.blocks.31.attn.value.lora_A True
# decoder.blocks.31.attn.value.lora_B True
# decoder.blocks.31.attn.out.weight False
# decoder.blocks.31.attn.out.bias False
# decoder.blocks.31.attn_ln.weight False
# decoder.blocks.31.attn_ln.bias False
# decoder.blocks.31.cross_attn.query.weight False
# decoder.blocks.31.cross_attn.query.bias True
# decoder.blocks.31.cross_attn.query.lora_A True
# decoder.blocks.31.cross_attn.query.lora_B True
# decoder.blocks.31.cross_attn.key.weight False
# decoder.blocks.31.cross_attn.value.weight False
# decoder.blocks.31.cross_attn.value.bias True
# decoder.blocks.31.cross_attn.value.lora_A True
# decoder.blocks.31.cross_attn.value.lora_B True
# decoder.blocks.31.cross_attn.out.weight False
# decoder.blocks.31.cross_attn.out.bias False
# decoder.blocks.31.cross_attn_ln.weight False
# decoder.blocks.31.cross_attn_ln.bias False
# decoder.blocks.31.mlp.0.weight False
# decoder.blocks.31.mlp.0.bias False
# decoder.blocks.31.mlp.2.weight False
# decoder.blocks.31.mlp.2.bias False
# decoder.blocks.31.mlp_ln.weight False
# decoder.blocks.31.mlp_ln.bias False
# decoder.ln.weight False
# decoder.ln.bias False

# %%
total = sum([param.nelement() for param in model.parameters() if param.requires_grad])
print('Number of parameter: % .4fM' % (total / 1e6))
# Out:
# Number of parameter:  2.2118M

# %%
# system = System(model, prompt_layer)

# total = sum([param.nelement() for param in system.parameters() if param.requires_grad])
# print('Number of parameter: % .4fM' % (total / 1e6))
# optimizer = torch.optim.AdamW([param for param in system.parameters() if param.requires_grad], lr=args.lr,
#                                 )
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1, verbose=True)
